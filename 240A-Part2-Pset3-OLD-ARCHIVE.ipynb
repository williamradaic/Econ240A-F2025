# %% [markdown]
# CLEAN THIS UP
# $$
# \frac{\pi(\theta' \mid Y)}{\pi(\theta \mid Y)}
# =
# \left(\frac{\sigma'^2}{\sigma^2}\right)^{-\frac{n+K}{2}}
# \left(\frac{\sigma^2}{\sigma'^2}\right)^{\alpha+1}
# \exp\!\Bigg[
# -\frac{1}{2\sigma'^2}\big(\|r'\|^2 + q'\big)
# +\frac{1}{2\sigma^2}\big(\|r\|^2 + q\big)
# -\frac{\beta}{\sigma'^2} + \frac{\beta}{\sigma^2}
# \Bigg].
# $$
# for
#
# * current: $(\theta = (\phi,\sigma^2))$
# * proposed: $(\theta' = (\phi',\sigma'^2))$
# * define residuals $(r = Y - X\phi), (r' = Y - X\phi')$
# * define prior quad forms
#   $(q = (\phi - \bar\phi)'\Lambda(\phi - \bar\phi))$,
#   $(q' = (\phi' - \bar\phi)'\Lambda(\phi' - \bar\phi))$
# * $(\alpha = \nu_0/2,\ \beta = \nu_0 s_0^2/2)$.
